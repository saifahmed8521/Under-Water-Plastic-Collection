# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/under

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/107.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/under

# %% [markdown]
# Custom Training

# %%
# %cd /content/drive/MyDrive/under
# Out:
# /content/drive/MyDrive/under

# %%
# !ls
# Out:
#  data   data.yaml  'Under Water Plastic Detection.ipynb'   yolov8s.pt

# %%
# %cd /content/drive/MyDrive/under

# !yolo task=detect mode=train model=yolov8s.pt data= data.yaml epochs=25 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/under
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml  weights

# %%
Image(filename='/content/drive/MyDrive/under/runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/under/runs/detect/train2/results.png',width=600)

# %%
Image(filename='/content/drive/MyDrive/under/runs/detect/train2/val_batch0_pred.jpg',width=600)

# %%
# !yolo task=detect mode=val model="/content/drive/MyDrive/under/runs/detect/train2/weights/best.pt" data= data.yaml
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/under/data/valid/labels.cache... 5 images, 0 backgrounds, 0 corrupt: 100% 5/5 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:10<00:00, 10.23s/it]
#                    all          5         17      0.827      0.529       0.63      0.324
# Speed: 19.0ms preprocess, 1919.6ms inference, 0.0ms loss, 9.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/under/runs/detect/train2/weights/best.pt conf=0.25 source=/content/drive/MyDrive/under/data/test/images
# Out:
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/5 /content/drive/MyDrive/under/data/test/images/25.jpeg: 512x640 2 Plastics, 544.3ms
# image 2/5 /content/drive/MyDrive/under/data/test/images/26.jpeg: 480x640 4 Plastics, 425.3ms
# image 3/5 /content/drive/MyDrive/under/data/test/images/28.jpeg: 384x640 6 Plastics, 352.8ms
# image 4/5 /content/drive/MyDrive/under/data/test/images/29.jpeg: 448x640 7 Plastics, 421.0ms
# image 5/5 /content/drive/MyDrive/under/data/test/images/30.jpeg: 384x640 3 Plastics, 329.9ms
# Speed: 4.5ms preprocess, 414.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
